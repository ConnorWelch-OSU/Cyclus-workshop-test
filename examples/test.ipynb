# %%
import cymetric as cym

db = cym.dbopen('tutorial_oncethrough.sqlite')

# %%
frame = cym.eval('Materials', db)
print(frame)
# Out:
#                                     SimId  QualId  ResourceId  ObjId  \
# 0    b76dec63-0c7e-45e0-9d96-e845a16fa5d3       1          12      9
# 1    b76dec63-0c7e-45e0-9d96-e845a16fa5d3       1          12      9
# 2    b76dec63-0c7e-45e0-9d96-e845a16fa5d3       1          22     18
# 3    b76dec63-0c7e-45e0-9d96-e845a16fa5d3       1          22     18
# 4    b76dec63-0c7e-45e0-9d96-e845a16fa5d3       1          23      9
# ..                                    ...     ...         ...    ...
# 621  b76dec63-0c7e-45e0-9d96-e845a16fa5d3     768        1984   1641
# 622  b76dec63-0c7e-45e0-9d96-e845a16fa5d3     788        2037   1687
# 623  b76dec63-0c7e-45e0-9d96-e845a16fa5d3     788        2037   1687
# 624  b76dec63-0c7e-45e0-9d96-e845a16fa5d3     789        2038   1686
# 625  b76dec63-0c7e-45e0-9d96-e845a16fa5d3     789        2038   1686
#
#      TimeCreated      NucId Units           Mass
# 0              0  922350000    kg    7110.000000
# ...

# %%
filtered_frame = cym.eval('Materials', db, conds=[('NucId', '==', 922350000)])
print(filtered_frame)
# Out:
#                                     SimId  QualId  ResourceId  ObjId  \
# 0    b76dec63-0c7e-45e0-9d96-e845a16fa5d3       1          12      9
# 1    b76dec63-0c7e-45e0-9d96-e845a16fa5d3       1          22     18
# 2    b76dec63-0c7e-45e0-9d96-e845a16fa5d3       1          23      9
# 3    b76dec63-0c7e-45e0-9d96-e845a16fa5d3       1          28     20
# 4    b76dec63-0c7e-45e0-9d96-e845a16fa5d3       1          29      9
# ..                                    ...     ...         ...    ...
# 271  b76dec63-0c7e-45e0-9d96-e845a16fa5d3     747        1930   1596
# 272  b76dec63-0c7e-45e0-9d96-e845a16fa5d3     767        1983   1642
# 273  b76dec63-0c7e-45e0-9d96-e845a16fa5d3     768        1984   1641
# 274  b76dec63-0c7e-45e0-9d96-e845a16fa5d3     788        2037   1687
# 275  b76dec63-0c7e-45e0-9d96-e845a16fa5d3     789        2038   1686
#
#      TimeCreated      NucId Units         Mass
# 0              0  922350000    kg  7110.000000
# ...

# %%
filtered_frame = cym.eval('AgentEntry', db, conds=[('Kind', '==', 'Facility'), ('AgentId', '>', 14)])
print(filtered_frame)
# Out:
#                                   SimId  AgentId      Kind  \
# 0  b76dec63-0c7e-45e0-9d96-e845a16fa5d3       15  Facility
# 1  b76dec63-0c7e-45e0-9d96-e845a16fa5d3       17  Facility
# 2  b76dec63-0c7e-45e0-9d96-e845a16fa5d3       18  Facility
# 3  b76dec63-0c7e-45e0-9d96-e845a16fa5d3       19  Facility
#
#                    Spec                    Prototype  ParentId  Lifetime  \
# 0     :cycamore:Reactor  1178MWe ReactorPlant Unit 1        14        -1
# 1      :cycamore:Source                  UraniumMine        16        -1
# 2  :cycamore:Enrichment              EnrichmentPlant        16        -1
# 3        :cycamore:Sink            NuclearRepository        16        -1
#
#    EnterTime
# 0          0
# 1          0
# 2          0
# 3          0

# %%
evaler = cym.Evaluator(db)
frame1 = evaler.eval('Materials')
frame2 = evaler.eval('AgentEntry', conds=[('Kind', '==', 'Facility')])

# %%
print(frame1)
# Out:
#                                     SimId  QualId  ResourceId  ObjId  \
# 0    b76dec63-0c7e-45e0-9d96-e845a16fa5d3       1          12      9
# 1    b76dec63-0c7e-45e0-9d96-e845a16fa5d3       1          12      9
# 2    b76dec63-0c7e-45e0-9d96-e845a16fa5d3       1          22     18
# 3    b76dec63-0c7e-45e0-9d96-e845a16fa5d3       1          22     18
# 4    b76dec63-0c7e-45e0-9d96-e845a16fa5d3       1          23      9
# ..                                    ...     ...         ...    ...
# 621  b76dec63-0c7e-45e0-9d96-e845a16fa5d3     768        1984   1641
# 622  b76dec63-0c7e-45e0-9d96-e845a16fa5d3     788        2037   1687
# 623  b76dec63-0c7e-45e0-9d96-e845a16fa5d3     788        2037   1687
# 624  b76dec63-0c7e-45e0-9d96-e845a16fa5d3     789        2038   1686
# 625  b76dec63-0c7e-45e0-9d96-e845a16fa5d3     789        2038   1686
#
#      TimeCreated      NucId Units           Mass
# 0              0  922350000    kg    7110.000000
# ...

# %%
print(frame2)
# Out:
#                                   SimId  AgentId      Kind  \
# 0  b76dec63-0c7e-45e0-9d96-e845a16fa5d3       15  Facility
# 1  b76dec63-0c7e-45e0-9d96-e845a16fa5d3       17  Facility
# 2  b76dec63-0c7e-45e0-9d96-e845a16fa5d3       18  Facility
# 3  b76dec63-0c7e-45e0-9d96-e845a16fa5d3       19  Facility
#
#                    Spec                    Prototype  ParentId  Lifetime  \
# 0     :cycamore:Reactor  1178MWe ReactorPlant Unit 1        14        -1
# 1      :cycamore:Source                  UraniumMine        16        -1
# 2  :cycamore:Enrichment              EnrichmentPlant        16        -1
# 3        :cycamore:Sink            NuclearRepository        16        -1
#
#    EnterTime
# 0          0
# 1          0
# 2          0
# 3          0

# %%
cym.exec_code("print(AgentEntry[:])", db)

# %%
cym.exec_code("Materials[ResourceId == 15].plot(x='NucId', y='Mass', kind='bar'); plt.show()", db)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 cym.exec_code("Materials[ResourceId == 15].plot(x='NucId', y='Mass', kind='bar'); plt.show()", db)
#
# File ~/.local/lib/python3.12/site-packages/cymetric/execution.py:227, in exec_code(code, db, write)
#     225 glb = {}
#     226 loc = ExecutionContext(evaler=evaler)
# --> 227 exec(code, glb, loc)
#
#     [... skipping hidden 1 frame]
#
# File /usr/lib/python3/dist-packages/pandas/plotting/_core.py:1032, in PlotAccessor.__call__(self, *args, **kwargs)
#    1029             label_name = label_kw or data.columns
#    1030             data.columns = label_name
# -> 1032 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /usr/lib/python3/dist-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...
